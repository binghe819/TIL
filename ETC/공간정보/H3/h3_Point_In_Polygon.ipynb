# %% [markdown]
# # H3를 이용한 Point In Polygon
#
# <br>
#
# <div class="toc"><ul class="toc-item"><li><span><a href="#H3를-이용한-Point-In-Polygon" data-toc-modified-id="H3를-이용한-Point-In-Polygon-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>H3를 이용한 Point In Polygon</a></span><ul class="toc-item"><li><span><a href="#Area-(지역,-Polygon)별-H3-셀을-생성하여-셀과-AreaId를-매핑시킨다." data-toc-modified-id="Area-(지역,-Polygon)별-H3-셀을-생성하여-셀과-AreaId를-매핑시킨다.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Area (지역, Polygon)별 H3 셀을 생성하여 셀과 AreaId를 매핑시킨다.</a></span></li><li><span><a href="#사용자가-위경도를-입력하면-해당-위치의-지정한-최소-Resolution과-최대-Resolution의-H3-셀로-변환한다." data-toc-modified-id="사용자가-위경도를-입력하면-해당-위치의-지정한-최소-Resolution과-최대-Resolution의-H3-셀로-변환한다.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>사용자가 위경도를 입력하면 해당 위치의 지정한 최소 Resolution과 최대 Resolution의 H3 셀로 변환한다.</a></span></li><li><span><a href="#사용자-위경도를-변환한-List을-순회하며-해당하는-AreaId가-존재하는지-확인한다." data-toc-modified-id="사용자-위경도를-변환한-List을-순회하며-해당하는-AreaId가-존재하는지-확인한다.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>사용자 위경도를 변환한 List을 순회하며 해당하는 AreaId가 존재하는지 확인한다.</a></span></li></ul></li></ul></div>
#
# <br>
#
# H3를 이용하여 Point In Polygon을 간단히 구현해보는 학습테스트입니다.
#
# PIP를 구현하는 과정은 아래와 같다.
#
# 1. Area (지역, Polygon)별 H3 셀을 생성하여 셀과 AreaId를 매핑시킨다.
#     * 최소 Resolution과 최대 Resolution을 정하여 H3셀로 최적화한다. (compact)
#     * 저장형태 - `key : value` = `H3 : AreaId`
# 2. 사용자가 위경도를 입력하면 해당 위치의 지정한 최소 Resolution과 최대 Resolution의 H3 셀로 변환한다.
#     * 위경도 -> `List<H3Cell>`
# 3. 사용자 위경도를 변환한 `List<H3Cell>`을 순회하며 해당하는 AreaId가 존재하는지 확인한다.
#     * `H3 : AreaId`의 Key(H3)를 이용하여 AreaId를 탐색하는 것. (시간 복잡도 - O(1))

# %%
import folium
import h3
import geopandas as gpd
from shapely.geometry import Polygon
h3.versions()
# Out:
# {'c': '3.7.1', 'python': '3.7.4'}

# %% [markdown]
# ## Area (지역, Polygon)별 H3 셀을 생성하여 셀과 AreaId를 매핑시킨다.
# * 최소 Resolution과 최대 Resolution을 정하여 H3셀로 최적화한다. (compact)
# * 저장형태 - `key : value` = `H3 : AreaId`

# %%
# 옥수동 GeoJson
oksu_area = {"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[127.01445372035877,37.54809716556332],[127.01519057405264,37.547067018782066],[127.01682578510314,37.545734088046544],[127.01971158208781,37.54514917644688],[127.02129552047927,37.543356952041016],[127.02268789647377,37.5416894537722],[127.02287476642073,37.54145247733586],[127.02502596652482,37.53872004668483],[127.0256997843901,37.53786411011561],[127.02156491849887,37.535530965877896],[127.02092441234515,37.53511935680614],[127.01719422667055,37.53742400398111],[127.01576373980122,37.5383059781119],[127.01478926311766,37.538901377441235],[127.012889891509,37.539313813299806],[127.01213660754814,37.539185649095785],[127.0121256959346,37.53915070095481],[127.01176468898241,37.53904214089355],[127.01153303960568,37.53898146832435],[127.00992598136419,37.5393714047437],[127.00947114947282,37.53957682723548],[127.00932275981805,37.53967748124033],[127.00833696037861,37.54185929062551],[127.00842516184942,37.54286466482798],[127.00857717612135,37.543889052496155],[127.00860603570271,37.5439797142403],[127.01068194070888,37.548078215345136],[127.01078235714807,37.548086518251225],[127.01081324310977,37.54809814744944],[127.01086705353879,37.54811841641107],[127.01147996885422,37.54841614618272],[127.01165764754505,37.548511522986345],[127.01320761955266,37.54994422861261],[127.01437412125692,37.54913421189207],[127.01445372035877,37.54809716556332]]]}}

# %%
# Area A에 대한 H3 정보를 생성한다.
min_h3_resolution = 6
base_h3_resolution = 12
area_a_h3_12 = list(h3.polyfill(oksu_area['geometry'], 12, geo_json_conformant=True))
area_a_h3_compacted = list(h3.compact(area_a_h3_12))

# 생성한 H3 정보와 Area A를 매핑한다.
db = {h3 : 'Area A' for h3 in area_a_h3_compacted}
display(db)
# Out:
# {'8b30e1d8b6d1fff': 'Area A',
#  '8c30e1ca59a91ff': 'Area A',
#  '8c30e1d8b0667ff': 'Area A',
#  '8b30e1d8b15bfff': 'Area A',
#  '8b30e1d8b6a9fff': 'Area A',
#  '8b30e1d8b8cbfff': 'Area A',
#  '8c30e1d8b1367ff': 'Area A',
#  '8c30e1d8b2999ff': 'Area A',
#  '8c30e1ca59319ff': 'Area A',
#  '8b30e1ca5995fff': 'Area A',
#  '8b30e1d8b448fff': 'Area A',
#  '8b30e1d8b29efff': 'Area A',
#  '8a30e1d8b117fff': 'Area A',
#  '8c30e1d8b3ab1ff': 'Area A',
#  '8b30e1d8b2a2fff': 'Area A',
#  '8c30e1d8b44e3ff': 'Area A',
#  '8c30e1d8bcc2bff': 'Area A',
#  '8c30e1d8bcc01ff': 'Area A',
#  '8c30e1d8b16adff': 'Area A',
#  '8c30e1ca598bdff': 'Area A',
#  '8c30e1d8b52dbff': 'Area A',
#  '8c30e1ca59317ff': 'Area A',
#  '8c30e1d8b125bff': 'Area A',
#  '8c30e1ca59897ff': 'Area A',
#  '8c30e1d8bcc07ff': 'Area A',
#  '8c30e1ca5992dff': 'Area A',
#  '8b30e1d8b68dfff': 'Area A',
#  '8c30e1ca5d2c9ff': 'Area A',
#  '8b30e1d8b15dfff': 'Area A',
#  '8c30e1d8b3ab9ff': 'Area A',
#  '8c30e1d8bc4ebff': 'Area A',
#  '8a30e1d8b12ffff': 'Area A',
#  '8c30e1d8b38b9ff': 'Area A',
#  '8b30e1d8b6d3fff': 'Area A',
#  '8c30e1d8b7aebff': 'Area A',
#  '8c30e1d8b05d5ff': 'Area A',
#  '8c30e1d8b44edff': 'Area A',
#  '8b30e1d8bc48fff': 'Area A',
#  '8b30e1d8b15afff': 'Area A',
#  '8c30e1d8b4251ff': 'Area A',
#  '8c30e1ca58161ff': 'Area A',
#  '8c30e1d8b1591ff': 'Area A',
#  '8c30e1d8b0621ff': 'Area A',
#  '8b30e1ca59adfff': 'Area A',
#  '8b30e1ca598dfff': 'Area A',
#  '8c30e1ca5d2d9ff': 'Area A',
#  '8b30e1ca5916fff': 'Area A',
#  '8c30e1d8bc5e1ff': 'Area A',
#  '8c30e1ca59111ff': 'Area A',
#  '8b30e1d8b78dfff': 'Area A',
#  '8c30e1d8bcec3ff': 'Area A',
#  '8b30e1d8b38afff': 'Area A',
#  '8c30e1ca5d2c1ff': 'Area A',
#  '8b30e1ca5935fff': 'Area A',
#  '8b30e1d8b29bfff': 'Area A',
#  '8c30e1d8b1357ff': 'Area A',
#  '8c30e1d8bcc03ff': 'Area A',
#  '8b30e1d8b131fff': 'Area A',
#  '8b30e1d8b05cfff': 'Area A',
#  '8b30e1ca5934fff': 'Area A',
#  '8c30e1d8b5283ff': 'Area A',
#  '8c30e1d8b52b3ff': 'Area A',
#  '8c30e1ca5d2c3ff': 'Area A',
#  '8c30e1d8b6a13ff': 'Area A',
#  '8c30e1d8b1351ff': 'Area A',
#  '8c30e1d8b3a1dff': 'Area A',
#  '8c30e1d8b05d1ff': 'Area A',
#  '8c30e1d8b8dd3ff': 'Area A',
#  '8b30e1d8bc5afff': 'Area A',
#  '8b30e1ca59abfff': 'Area A',
#  '8c30e1d8b6db9ff': 'Area A',
#  '8a30e1d8b397fff': 'Area A',
#  '8b30e1d8b146fff': 'Area A',
#  '8c30e1d8bc4e1ff': 'Area A',
#  '8c30e1d8b8c9dff': 'Area A',
#  '8c30e1d8b6aabff': 'Area A',
#  '8c30e1d8bcc27ff': 'Area A',
#  '8c30e1d8b2a5dff': 'Area A',
#  '8c30e1ca59989ff': 'Area A',
#  '8c30e1ca59a99ff': 'Area A',
#  '8c30e1d8bc4e3ff': 'Area A',
#  '8c30e1ca598b1ff': 'Area A',
#  '8c30e1d8b52b9ff': 'Area A',
#  '8c30e1d8b421bff': 'Area A',
#  '8b30e1ca5994fff': 'Area A',
#  '8b30e1ca5932fff': 'Area A',
#  '8c30e1d8b4281ff': 'Area A',
#  '8c30e1ca5d2ddff': 'Area A',
#  '8c30e1ca599e9ff': 'Area A',
#  '8b30e1d8b6adfff': 'Area A',
#  '8b30e1d8b2a3fff': 'Area A',
#  '8b30e1d8b142fff': 'Area A',
#  '8b30e1d8b123fff': 'Area A',
#  '8930e1d8b57ffff': 'Area A',
#  '8b30e1ca5915fff': 'Area A',
#  '8c30e1ca5d2dbff': 'Area A',
#  '8b30e1d8bcebfff': 'Area A',
#  '8b30e1d8b475fff': 'Area A',
#  '8c30e1d8bcc23ff': 'Area A',
#  '8b30e1d8bb96fff': 'Area A',
#  '8c30e1d8b78b9ff': 'Area A',
#  '8c30e1d8b8d23ff': 'Area A',
#  '8c30e1d8b5085ff': 'Area A',
#  '8b30e1d8bcc3fff': 'Area A',
#  '8b30e1d8b42cfff': 'Area A',
#  '8c30e1d8bc5c3ff': 'Area A',
#  '8c30e1d8bc5e3ff': 'Area A',
#  '8c30e1d8b044dff': 'Area A',
#  '8c30e1d8b4709ff': 'Area A',
#  '8c30e1ca5d651ff': 'Area A',
#  '8c30e1d8b16a9ff': 'Area A',
#  '8c30e1d8b6dabff': 'Area A',
#  '8c30e1ca598bbff': 'Area A',
#  '8c30e1d8b0625ff': 'Area A',
#  '8b30e1d8b29cfff': 'Area A',
#  '8b30e1d8b44dfff': 'Area A',
#  '8b30e1d8bce9fff': 'Area A',
#  '8c30e1d8bcee7ff': 'Area A',
#  '8c30e1d8b8dc3ff': 'Area A',
#  '8c30e1d8b3a11ff': 'Area A',
#  '8c30e1d8b3a41ff': 'Area A',
#  '8c30e1ca5989dff': 'Area A',
#  '8c30e1ca5926dff': 'Area A',
#  '8a30e1d8b467fff': 'Area A',
#  '8b30e1d8b7acfff': 'Area A',
#  '8c30e1d8b8d2dff': 'Area A',
#  '8c30e1ca58365ff': 'Area A',
#  '8c30e1d8b52d9ff': 'Area A',
#  '8b30e1d8b42dfff': 'Area A',
#  '8930e1d8b63ffff': 'Area A',
#  '8c30e1d8b3a87ff': 'Area A',
#  '8c30e1d8b1267ff': 'Area A',
#  '8930e1d8b0bffff': 'Area A',
#  '8b30e1d8b29afff': 'Area A',
#  '8c30e1ca5d2cdff': 'Area A',
#  '8b30e1d8b8dafff': 'Area A',
#  '8b30e1d8bcedfff': 'Area A',
#  '8a30e1d8b167fff': 'Area A',
#  '8c30e1d8b0407ff': 'Area A',
#  '8c30e1d8bcd13ff': 'Area A',
#  '8b30e1ca5988fff': 'Area A',
#  '8c30e1ca59939ff': 'Area A',
#  '8930e1d8b73ffff': 'Area A',
#  '8c30e1d8bcd11ff': 'Area A',
#  '8b30e1d8b042fff': 'Area A',
#  '8c30e1d8bc5e5ff': 'Area A',
#  '8b30e1d8b059fff': 'Area A',
#  '8c30e1d8b05d3ff': 'Area A',
#  '8b30e1d8b6d9fff': 'Area A',
#  '8b30e1d8b3aefff': 'Area A',
#  '8c30e1d8b040dff': 'Area A',
#  '8c30e1d8b8ce7ff': 'Area A',
#  '8c30e1d8b4219ff': 'Area A',
#  '8b30e1d8bc58fff': 'Area A',
#  '8b30e1d8b7a8fff': 'Area A',
#  '8c30e1d8b066dff': 'Area A',
#  '8b30e1d8b3a3fff': 'Area A',
#  '8a30e1d8b6cffff': 'Area A',
#  '8c30e1d8b440dff': 'Area A',
#  '8c30e1ca591edff': 'Area A',
#  '8c30e1d8b16a5ff': 'Area A',
#  '8b30e1d8bceafff': 'Area A',
#  '8c30e1d8b38b5ff': 'Area A',
#  '8b30e1ca599dfff': 'Area A',
#  '8c30e1d8b043dff': 'Area A',
#  '8c30e1d8b7ae7ff': 'Area A',
#  '8c30e1d8bb93dff': 'Area A',
#  '8b30e1d8b144fff': 'Area A',
#  '8c30e1d8b508bff': 'Area A',
#  '8c30e1d8b425dff': 'Area A',
#  '8c30e1ca59899ff': 'Area A',
#  '8c30e1d8bc4c3ff': 'Area A',
#  '8c30e1d8b6ae3ff': 'Area A',
#  '8c30e1ca59921ff': 'Area A',
#  '8b30e1d8bce8fff': 'Area A',
#  '8c30e1d8b04a5ff': 'Area A',
#  '8c30e1d8b78b3ff': 'Area A',
#  '8c30e1d8b3ab5ff': 'Area A',
#  '8c30e1d8b428bff': 'Area A',
#  '8b30e1d8b132fff': 'Area A',
#  '8c30e1d8b38d5ff': 'Area A',
#  '8b30e1d8bc5dfff': 'Area A',
#  '8c30e1d8b78c3ff': 'Area A',
#  '8b30e1d8b130fff': 'Area A',
#  '8c30e1d8b1353ff': 'Area A',
#  '8c30e1d8b78b1ff': 'Area A',
#  '8c30e1d8b281dff': 'Area A',
#  '8c30e1d8b2991ff': 'Area A',
#  '8c30e1d8b44ebff': 'Area A',
#  '8b30e1ca5914fff': 'Area A',
#  '8c30e1d8b0669ff': 'Area A',
#  '8c30e1d8b141dff': 'Area A',
#  '8c30e1d8b6d23ff': 'Area A',
#  '8c30e1d8b7aedff': 'Area A',
#  '8c30e1d8b50abff': 'Area A',
#  '8c30e1d8b8d2bff': 'Area A',
#  '8c30e1d8b42bbff': 'Area A',
#  '8c30e1d8b3a45ff': 'Area A',
#  '8c30e1d8b0627ff': 'Area A',
#  '8b30e1ca5910fff': 'Area A',
#  '8b30e1d8b3a2fff': 'Area A',
#  '8c30e1d8b8d21ff': 'Area A',
#  '8c30e1d8b0445ff': 'Area A',
#  '8c30e1d8b3a4dff': 'Area A',
#  '8c30e1ca59117ff': 'Area A',
#  '8c30e1ca59895ff': 'Area A',
#  '8c30e1d8b8d27ff': 'Area A',
#  '8c30e1d8b8c87ff': 'Area A',
#  '8b30e1d8b689fff': 'Area A',
#  '8c30e1ca59315ff': 'Area A',
#  '8c30e1d8b470dff': 'Area A',
#  '8c30e1d8bcd33ff': 'Area A',
#  '8c30e1d8bc4e7ff': 'Area A',
#  '8a30e1d8b6e7fff': 'Area A',
#  '8c30e1d8bcee3ff': 'Area A',
#  '8c30e1d8b14edff': 'Area A',
#  '8c30e1d8b1355ff': 'Area A',
#  '8c30e1d8b6d21ff': 'Area A',
#  '8930e1d8b67ffff': 'Area A',
#  '8c30e1ca5836dff': 'Area A',
#  '8b30e1d8b7a5fff': 'Area A',
#  '8c30e1d8b0661ff': 'Area A',
#  '8c30e1d8b05d9ff': 'Area A',
#  '8c30e1ca5993bff': 'Area A',
#  '8c30e1d8b1347ff': 'Area A',
#  '8b30e1d8b16efff': 'Area A',
#  '8930e1d8b77ffff': 'Area A',
#  '8c30e1d8b8c91ff': 'Area A',
#  '8c30e1ca59931ff': 'Area A',
#  '8c30e1ca599ebff': 'Area A',
#  '8c30e1d8b428dff': 'Area A',
#  '8b30e1d8b6d4fff': 'Area A',
#  '8b30e1d8b286fff': 'Area A',
#  '8b30e1d8bc59fff': 'Area A',
#  '8c30e1d8b8c97ff': 'Area A',
#  '8c30e1d8b8dc7ff': 'Area A',
#  '8a30e1d8b057fff': 'Area A',
#  '8c30e1d8b7ae3ff': 'Area A',
#  '8b30e1d8b8cafff': 'Area A',
#  '8c30e1d8b7a13ff': 'Area A',
#  '8a30e1ca5987fff': 'Area A',
#  '8c30e1d8b443bff': 'Area A',
#  '8c30e1d8b38b7ff': 'Area A',
#  '8b30e1d8b2a4fff': 'Area A',
#  '8c30e1d8b50cbff': 'Area A',
#  '8c30e1d8b1363ff': 'Area A',
#  '8c30e1d8b7aa9ff': 'Area A',
#  '8b30e1d8b7adfff': 'Area A',
#  '8c30e1ca59999ff': 'Area A',
#  '8c30e1d8b52d3ff': 'Area A',
#  '8c30e1d8b136bff': 'Area A',
#  '8c30e1d8b1419ff': 'Area A',
#  '8b30e1d8b158fff': 'Area A',
#  '8c30e1d8b135dff': 'Area A',
#  '8b30e1ca5930fff': 'Area A',
#  '8a30e1d8b297fff': 'Area A',
#  '8c30e1d8b471bff': 'Area A',
#  '8b30e1d8b50bfff': 'Area A',
#  '8c30e1d8b44abff': 'Area A',
#  '8c30e1d8b7a11ff': 'Area A',
#  '8c30e1d8b1599ff': 'Area A',
#  '8c30e1d8b29d1ff': 'Area A',
#  '8c30e1d8b52b1ff': 'Area A',
#  '8c30e1d8b4769ff': 'Area A',
#  '8b30e1d8b05efff': 'Area A',
#  '8c30e1d8b2997ff': 'Area A',
#  '8c30e1d8b285dff': 'Area A',
#  '8b30e1d8b6defff': 'Area A',
#  '8c30e1d8b38ddff': 'Area A',
#  '8b30e1d8bb92fff': 'Area A',
#  '8c30e1d8b688bff': 'Area A',
#  '8c30e1ca599edff': 'Area A',
#  '8c30e1d8b29d7ff': 'Area A',
#  '8a30e1ca59b7fff': 'Area A',
#  '8c30e1d8b8d25ff': 'Area A',
#  '8c30e1d8bcc5bff': 'Area A',
#  '8c30e1d8b05ddff': 'Area A',
#  '8c30e1d8b4253ff': 'Area A',
#  '8b30e1d8b6d5fff': 'Area A',
#  '8c30e1d8bc5ebff': 'Area A',
#  '8b30e1d8bc4afff': 'Area A',
#  '8b30e1d8b8dbfff': 'Area A',
#  '8c30e1d8b7a1dff': 'Area A',
#  '8c30e1d8bcd1bff': 'Area A',
#  '8c30e1ca5d65dff': 'Area A',
#  '8c30e1d8b3a55ff': 'Area A',
#  '8c30e1d8b1595ff': 'Area A',
#  '8b30e1d8b6dcfff': 'Area A',
#  '8c30e1d8b3a8dff': 'Area A',
#  '8b30e1ca59aafff': 'Area A',
#  '8c30e1d8b78bbff': 'Area A',
#  '8c30e1d8b29d9ff': 'Area A',
#  '8c30e1d8b6dadff': 'Area A',
#  '8c30e1d8b7889ff': 'Area A',
#  '8c30e1d8b52bbff': 'Area A',
#  '8b30e1d8b2a0fff': 'Area A',
#  '8b30e1d8b3a6fff': 'Area A',
#  '8c30e1d8b7aa3ff': 'Area A',
#  '8c30e1ca5992bff': 'Area A',
#  '8b30e1ca59aefff': 'Area A',
#  '8b30e1d8b6a8fff': 'Area A',
#  '8930e1d8b0fffff': 'Area A',
#  '8c30e1d8b6aebff': 'Area A',
#  '8c30e1d8b2a15ff': 'Area A',
#  '8c30e1d8b0665ff': 'Area A',
#  '8c30e1d8bc5e7ff': 'Area A',
#  '8c30e1d8b7a1bff': 'Area A',
#  '8c30e1ca5d653ff': 'Area A',
#  '8b30e1d8b058fff': 'Area A',
#  '8b30e1d8b7a9fff': 'Area A',
#  '8b30e1ca599cfff': 'Area A',
#  '8c30e1d8b159dff': 'Area A',
#  '8c30e1d8b8dd7ff': 'Area A',
#  '8c30e1d8b7881ff': 'Area A',
#  '8930e1d8b03ffff': 'Area A',
#  '8b30e1d8b05bfff': 'Area A',
#  '8c30e1d8b4713ff': 'Area A',
#  '8c30e1d8b0435ff': 'Area A',
#  '8c30e1d8bb935ff': 'Area A',
#  '8b30e1d8bc4dfff': 'Area A',
#  '8b30e1d8b284fff': 'Area A',
#  '8c30e1ca5d669ff': 'Area A',
#  '8c30e1d8b1253ff': 'Area A',
#  '8c30e1d8b6d27ff': 'Area A',
#  '8b30e1d8b6abfff': 'Area A',
#  '8b30e1ca5991fff': 'Area A',
#  '8b30e1d8b122fff': 'Area A',
#  '8b30e1d8b143fff': 'Area A',
#  '8a30e1d8b6f7fff': 'Area A',
#  '8a30e1d8b46ffff': 'Area A',
#  '8b30e1ca5933fff': 'Area A',
#  '8c30e1d8bcc21ff': 'Area A',
#  '8b30e1d8b444fff': 'Area A',
#  '8c30e1d8bcec7ff': 'Area A',
#  '8c30e1ca59265ff': 'Area A',
#  '8c30e1d8b78cbff': 'Area A',
#  '8c30e1ca598b9ff': 'Area A',
#  '8c30e1d8b5089ff': 'Area A',
#  '8c30e1d8b04a7ff': 'Area A',
#  '8c30e1d8b50c3ff': 'Area A',
#  '8c30e1ca598b5ff': 'Area A',
#  '8c30e1d8bcc53ff': 'Area A',
#  '8b30e1ca59acfff': 'Area A',
#  '8b30e1d8b38efff': 'Area A',
#  '8b30e1d8b6d6fff': 'Area A',
#  '8c30e1ca5d2cbff': 'Area A',
#  '8c30e1d8b8c9bff': 'Area A',
#  '8c30e1d8b1343ff': 'Area A',
#  '8b30e1ca598efff': 'Area A',
#  '8c30e1ca5d65bff': 'Area A',
#  '8c30e1d8b2995ff': 'Area A',
#  '8b30e1d8b05afff': 'Area A',
#  '8c30e1d8b7a17ff': 'Area A',
#  '8c30e1d8b4403ff': 'Area A',
#  '8c30e1d8b2851ff': 'Area A',
#  '8a30e1d8b157fff': 'Area A',
#  '8a30e1d8b39ffff': 'Area A',
#  '8c30e1d8b7aabff': 'Area A',
#  '8b30e1d8b133fff': 'Area A',
#  '8c30e1d8b1411ff': 'Area A',
#  '8a30e1d8b2b7fff': 'Area A',
#  '8c30e1ca59065ff': 'Area A',
#  '8c30e1d8b6d2dff': 'Area A',
#  '8c30e1d8bb945ff': 'Area A',
#  '8c30e1ca59a9dff': 'Area A',
#  '8c30e1d8b2a55ff': 'Area A',
#  '8b30e1d8b8defff': 'Area A',
#  '8c30e1d8b1417ff': 'Area A',
#  '8b30e1d8b8d3fff': 'Area A',
#  '8c30e1d8bcc0bff': 'Area A',
#  '8c30e1ca59891ff': 'Area A',
#  '8c30e1d8b52d1ff': 'Area A',
#  '8b30e1d8b120fff': 'Area A',
#  '8b30e1ca59a8fff': 'Area A',
#  '8b30e1d8b298fff': 'Area A',
#  '8c30e1ca5d655ff': 'Area A',
#  '8c30e1d8b8c93ff': 'Area A',
#  '8c30e1d8b135bff': 'Area A',
#  '8c30e1d8b1257ff': 'Area A',
#  '8c30e1d8b4213ff': 'Area A',
#  '8b30e1d8b121fff': 'Area A',
#  '8b30e1d8bc49fff': 'Area A',
#  '8b30e1d8b6ddfff': 'Area A',
#  '8c30e1d8b3a47ff': 'Area A',
#  '8b30e1d8b441fff': 'Area A',
#  '8b30e1ca5996fff': 'Area A',
#  '8a30e1d8b077fff': 'Area A',
#  '8c30e1d8b44e7ff': 'Area A',
#  '8c30e1d8b471dff': 'Area A',
#  '8c30e1ca59119ff': 'Area A',
#  '8c30e1d8b38b1ff': 'Area A',
#  '8c30e1d8b7a19ff': 'Area A',
#  '8b30e1d8b38cfff': 'Area A',
#  '8c30e1d8b29d3ff': 'Area A',
#  '8c30e1d8b2a1dff': 'Area A',
#  '8c30e1d8b3a15ff': 'Area A',
#  '8c30e1d8b5087ff': 'Area A',
#  '8c30e1d8b4257ff': 'Area A',
#  '8c30e1d8b299dff': 'Area A',
#  '8c30e1d8b2855ff': 'Area A',
#  '8b30e1ca5913fff': 'Area A',
#  '8c30e1d8b7aa7ff': 'Area A',
#  '8a30e1d8b3b7fff': 'Area A',
#  '8b30e1d8b280fff': 'Area A',
#  '8b30e1d8b3aafff': 'Area A',
#  '8c30e1d8b476bff': 'Area A',
#  '8c30e1d8b6d2bff': 'Area A',
#  '8c30e1d8b4283ff': 'Area A',
#  '8c30e1d8b0447ff': 'Area A',
#  '8b30e1d8b140fff': 'Area A',
#  '8c30e1d8b3a85ff': 'Area A',
#  '8c30e1d8b4711ff': 'Area A',
#  '8b30e1ca5d64fff': 'Area A',
#  '8c30e1d8b44e1ff': 'Area A',
#  '8b30e1d8b429fff': 'Area A',
#  '8b30e1d8b15efff': 'Area A',
#  '8c30e1ca59311ff': 'Area A',
#  '8c30e1d8bc4c7ff': 'Area A',
#  '8c30e1d8b8dd5ff': 'Area A',
#  '8c30e1ca59893ff': 'Area A',
#  '8b30e1d8b8d9fff': 'Area A',
#  '8b30e1d8b509fff': 'Area A',
#  '8c30e1ca59a95ff': 'Area A',
#  '8c30e1d8b78c1ff': 'Area A',
#  '8c30e1ca59115ff': 'Area A',
#  '8c30e1d8b14e5ff': 'Area A',
#  '8a30e1d8b11ffff': 'Area A',
#  '8c30e1d8b788bff': 'Area A',
#  '8c30e1ca59923ff': 'Area A',
#  '8c30e1d8b29ddff': 'Area A',
#  '8a30e1d8b6c7fff': 'Area A',
#  '8c30e1d8b8c83ff': 'Area A',
#  '8c30e1d8b425bff': 'Area A',
#  '8a30e1d8b107fff': 'Area A',
#  '8b30e1d8b2a6fff': 'Area A',
#  '8c30e1d8b6a53ff': 'Area A',
#  '8c30e1d8b0405ff': 'Area A',
#  '8b30e1ca5990fff': 'Area A',
#  '8c30e1d8b062dff': 'Area A',
#  '8b30e1d8b7abfff': 'Area A',
#  '8c30e1d8b8dddff': 'Area A',
#  '8c30e1d8b470bff': 'Area A',
#  '8c30e1d8b2a57ff': 'Area A',
#  '8c30e1d8b5083ff': 'Area A',
#  '8c30e1d8b7ae1ff': 'Area A',
#  '8c30e1d8bb94dff': 'Area A',
#  '8c30e1d8b3ab7ff': 'Area A',
#  '8c30e1d8b6a19ff': 'Area A',
#  '8c30e1ca5906dff': 'Area A',
#  '8b30e1d8b44cfff': 'Area A',
#  '8b30e1d8b449fff': 'Area A',
#  '8c30e1d8b168dff': 'Area A',
#  '8b30e1d8b789fff': 'Area A',
#  '8c30e1d8b7ae9ff': 'Area A',
#  '8c30e1d8b3a17ff': 'Area A',
#  '8b30e1d8b16cfff': 'Area A',
#  '8c30e1d8b8dd1ff': 'Area A',
#  '8c30e1d8b1597ff': 'Area A',
#  '8c30e1d8bcc51ff': 'Area A',
#  '8c30e1d8b7aa1ff': 'Area A',
#  '8b30e1d8b44bfff': 'Area A',
#  '8b30e1d8b046fff': 'Area A',
#  '8c30e1d8b2815ff': 'Area A',
#  '8c30e1ca591e5ff': 'Area A',
#  '8c30e1d8bc5c7ff': 'Area A',
#  '8c30e1ca5993dff': 'Area A',
#  '8c30e1d8bcd17ff': 'Area A',
#  '8c30e1d8b52d7ff': 'Area A',
#  '8b30e1d8bc5bfff': 'Area A',
#  '8c30e1ca59929ff': 'Area A',
#  '8b30e1d8b282fff': 'Area A',
#  '8b30e1d8b283fff': 'Area A',
#  '8c30e1d8b2857ff': 'Area A',
#  '8c30e1d8b1263ff': 'Area A',
#  '8c30e1d8b1365ff': 'Area A',
#  '8c30e1ca5998bff': 'Area A',
#  '8c30e1d8bcc57ff': 'Area A',
#  '8b30e1d8b6acfff': 'Area A',
#  '8c30e1d8b44e9ff': 'Area A',
#  '8a30e1d8b6effff': 'Area A',
#  '8c30e1d8b2859ff': 'Area A',
#  '8c30e1d8b0437ff': 'Area A',
#  '8c30e1d8b1415ff': 'Area A',
#  '8c30e1d8b1361ff': 'Area A',
#  '8b30e1d8b529fff': 'Area A',
#  '8c30e1d8b6a59ff': 'Area A',
#  '8b30e1d8b15cfff': 'Area A',
#  '8a30e1d8b177fff': 'Area A',
#  '8b30e1d8b445fff': 'Area A',
#  '8b30e1d8b145fff': 'Area A',
#  '8c30e1ca5931dff': 'Area A',
#  '8b30e1d8b50dfff': 'Area A',
#  '8c30e1d8bb90dff': 'Area A',
#  '8c30e1d8b8c95ff': 'Area A',
#  '8a30e1d8b10ffff': 'Area A',
#  '8c30e1d8b8c85ff': 'Area A',
#  '8b30e1ca5936fff': 'Area A',
#  '8c30e1ca598b3ff': 'Area A',
#  '8c30e1d8b440bff': 'Area A',
#  '8a30e1d8bccffff': 'Area A',
#  '8b30e1ca5912fff': 'Area A',
#  '8c30e1d8b6a5bff': 'Area A',
#  '8b30e1d8bcc1fff': 'Area A',
#  '8c30e1d8b4401ff': 'Area A',
#  '8c30e1d8b78c9ff': 'Area A',
#  '8c30e1d8b3a43ff': 'Area A',
#  '8c30e1d8b1255ff': 'Area A',
#  '8c30e1d8b44a9ff': 'Area A',
#  '8c30e1d8b4289ff': 'Area A',
#  '8c30e1ca5d659ff': 'Area A',
#  '8b30e1d8bc4bfff': 'Area A',
#  '8b30e1ca598afff': 'Area A',
#  '8b30e1d8b6d8fff': 'Area A',
#  '8b30e1d8b3a0fff': 'Area A',
#  '8c30e1ca5816dff': 'Area A',
#  '8c30e1d8bb905ff': 'Area A',
#  '8c30e1d8b6a1bff': 'Area A',
#  '8c30e1d8b6da9ff': 'Area A',
#  '8b30e1ca598cfff': 'Area A',
#  '8a30e1d8bcdffff': 'Area A',
#  '8c30e1d8b05d7ff': 'Area A',
#  '8c30e1d8b5081ff': 'Area A',
#  '8c30e1d8b4719ff': 'Area A',
#  '8c30e1ca5911dff': 'Area A',
#  '8a30e1d8b387fff': 'Area A',
#  '8c30e1d8bc4e5ff': 'Area A',
#  '8b30e1d8b474fff': 'Area A',
#  '8c30e1d8b4259ff': 'Area A',
#  '8c30e1d8b8ddbff': 'Area A',
#  '8c30e1d8b68cbff': 'Area A',
#  '8c30e1ca5d2d1ff': 'Area A',
#  '8c30e1ca58169ff': 'Area A',
#  '8b30e1d8b388fff': 'Area A',
#  '8c30e1d8b7883ff': 'Area A',
#  '8c30e1d8b3abdff': 'Area A',
#  '8c30e1d8b1251ff': 'Area A',
#  '8930e1d8b1bffff': 'Area A',
#  '8c30e1d8b29d5ff': 'Area A',
#  '8c30e1d8b52b7ff': 'Area A',
#  '8c30e1ca59a97ff': 'Area A',
#  '8c30e1d8b4409ff': 'Area A',
#  '8c30e1d8b6d29ff': 'Area A',
#  '8a30e1ca59a7fff': 'Area A',
#  '8c30e1d8b2a51ff': 'Area A',
#  '8c30e1d8b8dc5ff': 'Area A',
#  '8b30e1d8b6d0fff': 'Area A',
#  '8c30e1d8bceebff': 'Area A',
#  '8b30e1d8b8d8fff': 'Area A',
#  '8c30e1d8b38bdff': 'Area A'}

# %% [markdown]
# <br>
#
# ## 사용자가 위경도를 입력하면 해당 위치의 지정한 최소 Resolution과 최대 Resolution의 H3 셀로 변환한다.
# * 위경도 -> `List<H3Cell>`

# %%
# 사용자 위치정보 -> List<H3Cell> 변환 함수 정의
def geo_to_h3(lat, lng, min_resolution, base_resolution):
    result = []
    for resolution in range(min_resolution, base_resolution):
        h3_cell = h3.geo_to_h3(lat, lng, resolution)
        result.append(h3_cell)
    return result

# 사용자 위치정보 -> List<H3Cell> 변환
user_a_geo = [37.5404, 127.0184]
user_a_h3_cells = geo_to_h3(user_a_geo[0], user_a_geo[1], min_h3_resolution, base_h3_resolution)
print('user_a 위경도를 H3로 변환한 결과: ', user_a_h3_cells)

user_b_geo = [37.5448, 127.0247]
user_b_h3_cells = geo_to_h3(user_b_geo[0], user_b_geo[1], min_h3_resolution, base_h3_resolution)
print('user_a 위경도를 H3로 변환한 결과: ', user_b_h3_cells)
# Out:
# user_a 위경도를 H3로 변환한 결과:  ['8630e1d8fffffff', '8730e1d8bffffff', '8830e1d8b7fffff', '8930e1d8b77ffff', '8a30e1d8b757fff', '8b30e1d8b750fff']
# user_a 위경도를 H3로 변환한 결과:  ['8630e1d8fffffff', '8730e1d8bffffff', '8830e1d8b3fffff', '8930e1d8b2fffff', '8a30e1d8b2effff', '8b30e1d8b2edfff']

# %% [markdown]
# <br>
#
# ## 사용자 위경도를 변환한 List<H3Cell>을 순회하며 해당하는 AreaId가 존재하는지 확인한다.
# * `H3 : AreaId`의 `Key`(H3)를 이용하여 AreaId를 탐색하는 것. (시간 복잡도 - O(1))

# %%
# 유저가 속하는 Area 반환 함수 정의
def what_area_is_in(db, h3_cells):
    result = set()
    for cell in h3_cells:
        if (db.get(cell) is not None):
            result.add(db.get(cell))
    return result

# 유저가 속하는 Area 확인
user_a_result = what_area_is_in(db, user_a_h3_cells)
user_b_result = what_area_is_in(db, user_b_h3_cells)

# 결과 출력
print(f'유저 a가 속하는 지점은 {"없습니다" if not user_a_result else user_a_result}')
print(f'유저 b가 속하는 지점은 {"없습니다" if not user_b_result else user_b_result}')
# Out:
# 유저 a가 속하는 지점은 {'Area A'}
# 유저 b가 속하는 지점은 없습니다
